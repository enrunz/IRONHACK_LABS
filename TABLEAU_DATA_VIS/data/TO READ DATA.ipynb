# %%
import pandas as pd

# %%
data=pd.read_csv('nfl_football_team_stats.csv')
data.head()
# Out:
#    Year     Date  GameNumber GameLocation                Team  TeamScore  \
# 0  2010   9/9/10           1         Away   Minnesota Vikings          9
# 1  2010   9/9/10           1         Home  New Orleans Saints         14
# 2  2010  9/12/10           1         Away   Arizona Cardinals         17
# 3  2010  9/12/10           1         Away     Atlanta Falcons          9
# 4  2010  9/12/10           1         Away   Carolina Panthers         18
#
#               Opponent  OppponentScore Result  PassingAttempts  ...  \
# 0   New Orleans Saints              14   Loss               27  ...
# 1    Minnesota Vikings               9    Win               36  ...
# 2       St. Louis Rams              13    Win               41  ...
# 3  Pittsburgh Steelers              15   Loss               44  ...
# 4      New York Giants              31   Loss               35  ...
#
#    KickReturnTouchdowns  KickReturnYards  PuntReturnAttempts  \
# ...

# %%
data['GameLocation'].unique()
# Out:
# array(['Away', 'Home', 'Neutral'], dtype=object)

# %%
len(data)
# Out:
# 4093

# %%
data[(data['GameLocation']=='Neutral')]
# Out:
#       Year    Date  GameNumber GameLocation                  Team  TeamScore  \
# 532   2010  2/6/11          19      Neutral   Pittsburgh Steelers         25
# 533   2010  2/6/11          20      Neutral     Green Bay Packers         31
# 1067  2011  2/5/12          19      Neutral  New England Patriots         17
# 1068  2011  2/5/12          20      Neutral       New York Giants         21
# 1601  2012  2/3/13          19      Neutral   San Francisco 49ers         31
# 1602  2012  2/3/13          20      Neutral      Baltimore Ravens         34
# 2135  2013  2/2/14          19      Neutral        Denver Broncos          8
# 2136  2013  2/2/14          19      Neutral      Seattle Seahawks         43
# 2669  2014  2/1/15          19      Neutral  New England Patriots         28
# 2670  2014  2/1/15          19      Neutral      Seattle Seahawks         24
# 3203  2015  2/7/16          19      Neutral     Carolina Panthers         10
# ...

# %%
data[(data['Year']==2011)&(data['GameLocation']=='Away')]
# Out:
#       Year     Date  GameNumber GameLocation                Team  TeamScore  \
# 534   2011   9/8/11           1         Away  New Orleans Saints         34
# 536   2011  9/11/11           1         Away     Atlanta Falcons         12
# 537   2011  9/11/11           1         Away       Buffalo Bills         41
# 538   2011  9/11/11           1         Away   Carolina Panthers         21
# 539   2011  9/11/11           1         Away  Cincinnati Bengals         27
# ...    ...      ...         ...          ...                 ...        ...
# 1058  2011  1/14/12          18         Away  New Orleans Saints         32
# 1061  2011  1/15/12          18         Away      Houston Texans         13
# 1062  2011  1/15/12          18         Away     New York Giants         37
# 1063  2011  1/22/12          18         Away    Baltimore Ravens         20
# 1066  2011  1/22/12          19         Away     New York Giants         20
#
# ...

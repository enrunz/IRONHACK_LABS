# %% [markdown]
# # Challenge 1: Fork Languages
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# Obtain the full list of forks created from the main lab repo via Github API.
#
# Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]
#
# Again, the documentation of Github API is here.

# %%
import requests 
import pandas as pd
import json

# %%
df=pd.DataFrame()
for i in range(2):
    api_url=f'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/forks?page={i}'
    token='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'
    headers={"Authorization": "Bearer {}".format(token)}
    respuesta=requests.get(api_url, headers=headers)
    x=respuesta.json()
    df=df.append(x,ignore_index=True)
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_33059/2886141766.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(x,ignore_index=True)
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_33059/2886141766.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(x,ignore_index=True)

# %%
df
# Out:
#            id                           node_id                    name  \
# 0   528225470                      R_kgDOH3wUvg       lab-API_SCAVANGER
# 1   528181046                      R_kgDOH3tnNg  lab-api-scavenger-game
# 2   496048333                      R_kgDOHZEYzQ  lab-api-scavenger-game
# 3   478379299                      R_kgDOHIN9Iw  lab-api-scavenger-game
# 4   478312893                      R_kgDOHIJ5vQ  lab-api-scavenger-game
# ..        ...                               ...                     ...
# 57  405138838  MDEwOlJlcG9zaXRvcnk0MDUxMzg4Mzg=  lab-api-scavenger-game
# 58  405138579  MDEwOlJlcG9zaXRvcnk0MDUxMzg1Nzk=  lab-api-scavenger-game
# 59  405138572  MDEwOlJlcG9zaXRvcnk0MDUxMzg1NzI=  lab-api-scavenger-game
# 60  405138488  MDEwOlJlcG9zaXRvcnk0MDUxMzg0ODg=  lab-api-scavenger-game
# 61  405138253  MDEwOlJlcG9zaXRvcnk0MDUxMzgyNTM=  lab-api-scavenger-game
#
#                                 full_name  private  \
# ...

# %%
api_url='https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/forks'
token='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'
headers={"Authorization": "Bearer {}".format(token)}
respuesta=requests.get(api_url, headers=headers)

# %%
DATA=respuesta.json()
DATA
# Out:
# [{'id': 528225470,
#   'node_id': 'R_kgDOH3wUvg',
#   'name': 'lab-API_SCAVANGER',
#   'full_name': 'enrunz/lab-API_SCAVANGER',
#   'private': False,
#   'owner': {'login': 'enrunz',
#    'id': 105838147,
#    'node_id': 'U_kgDOBk72Qw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105838147?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enrunz',
#    'html_url': 'https://github.com/enrunz',
#    'followers_url': 'https://api.github.com/users/enrunz/followers',
#    'following_url': 'https://api.github.com/users/enrunz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/enrunz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/enrunz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/enrunz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/enrunz/orgs',
#    'repos_url': 'https://api.github.com/users/enrunz/repos',
# ...

# %%
df.keys()
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
df[['language','full_name','fork','forks']]
# Out:
#             language                                    full_name  fork  forks
# 0               None                     enrunz/lab-API_SCAVANGER  True      0
# 1   Jupyter Notebook          Katiahsotelo/lab-api-scavenger-game  True      0
# 2   Jupyter Notebook         alejandrojile/lab-api-scavenger-game  True      0
# 3   Jupyter Notebook           FranciscoEP/lab-api-scavenger-game  True      0
# 4   Jupyter Notebook        JoseVelazquezR/lab-api-scavenger-game  True      0
# 5   Jupyter Notebook     DanielAguilar1994/lab-api-scavenger-game  True      0
# 6   Jupyter Notebook            Moises1009/lab-api-scavenger-game  True      0
# 7   Jupyter Notebook  JoaquinGonzalezSimon/lab-api-scavenger-game  True      0
# 8   Jupyter Notebook          DanielRamTen/lab-api-scavenger-game  True      0
# 9   Jupyter Notebook          hiler-hutter/lab-api-scavenger-game  True      0
# 10              None               HctorJG/lab-api-scavenger-game  True      0
# ...

# %%
jason=[]
for i in range(2):
    api_url=f'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/forks?page={i}'
    token='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'
    headers={"Authorization": "Bearer {}".format(token)}
    respuesta=requests.get(api_url, headers=headers)
    x=respuesta.json()
    jason.append(x)

# %%
jason
# Out:
# [[{'id': 528225470,
#    'node_id': 'R_kgDOH3wUvg',
#    'name': 'lab-API_SCAVANGER',
#    'full_name': 'enrunz/lab-API_SCAVANGER',
#    'private': False,
#    'owner': {'login': 'enrunz',
#     'id': 105838147,
#     'node_id': 'U_kgDOBk72Qw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/105838147?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/enrunz',
#     'html_url': 'https://github.com/enrunz',
#     'followers_url': 'https://api.github.com/users/enrunz/followers',
#     'following_url': 'https://api.github.com/users/enrunz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/enrunz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/enrunz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/enrunz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/enrunz/orgs',
#     'repos_url': 'https://api.github.com/users/enrunz/repos',
# ...

# %%
lang=[]
for i in jason:
    for j in i:
        for key,value in j.items():
            if key == 'language':
                lang.append(value)
                
set(lang)
# Out:
# [{'Jupyter Notebook', None, 'Python'}]

# %%
array_lang=[]
for i in set(lang):
    array_lang.append(i)

# %%
array_lang
# Out:
# ['Jupyter Notebook', 'Python', None]

# %% [markdown]
# # Challenge 2: Count Commits
# Count how many commits were made in the past week.
#
# Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
df[['commits_url', 'git_commits_url']]
# Out:
#                                           commits_url  \
# 0   https://api.github.com/repos/enrunz/lab-API_SC...
# 1   https://api.github.com/repos/Katiahsotelo/lab-...
# 2   https://api.github.com/repos/alejandrojile/lab...
# 3   https://api.github.com/repos/FranciscoEP/lab-a...
# 4   https://api.github.com/repos/JoseVelazquezR/la...
# 5   https://api.github.com/repos/DanielAguilar1994...
# 6   https://api.github.com/repos/Moises1009/lab-ap...
# 7   https://api.github.com/repos/JoaquinGonzalezSi...
# 8   https://api.github.com/repos/DanielRamTen/lab-...
# 9   https://api.github.com/repos/hiler-hutter/lab-...
# 10  https://api.github.com/repos/HctorJG/lab-api-s...
# 11  https://api.github.com/repos/Paola-LMaturano/l...
# 12  https://api.github.com/repos/juan1309-ctr/lab-...
# 13  https://api.github.com/repos/indira-percastigu...
# 14  https://api.github.com/repos/matsreds/lab-api-...
# 15  https://api.github.com/repos/dgonzalez1065/lab...
# ...

# %%
jason2=[]
for i in range(1):
    api_url=f'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/commits?page={i}'
    token='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'
    headers={"Authorization": "Bearer {}".format(token)}
    respuesta=requests.get(api_url, headers=headers)
    x=respuesta.json()
    jason2.append(x)

# %%
commits=[]
for i in jason2:
     for j in i:
        for key,value in j.items():
            if key=='commit':
                commits.append(value)

# %%
commits
# Out:
# [{'author': {'name': 'daniloxxv',
#    'email': 'danilosoares@gmail.com',
#    'date': '2019-06-25T17:26:30Z'},
#   'committer': {'name': 'daniloxxv',
#    'email': 'danilosoares@gmail.com',
#    'date': '2019-06-25T17:26:30Z'},
#   'message': 'Uploading module 1 labs',
#   'tree': {'sha': '630fb3256855111b1e78d609c4ce1964a9fdb47a',
#    'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/trees/630fb3256855111b1e78d609c4ce1964a9fdb47a'},
#   'url': 'https://api.github.com/repos/Data-FT-MX/lab-api-scavenger-game/git/commits/ac6d42854434acfafe92b60fdf2ed0b038de2070',
#   'comment_count': 0,
#   'verification': {'verified': False,
#    'reason': 'unsigned',
#    'signature': None,
#    'payload': None}}]

# %% [markdown]
# # Challenge 3: Hidden Cold Joke
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# Notes:
#
# Github API documentation can be found here.
#
# You will need to study the Github API documentation to decide which API endpoint to call and what parameters to use in order to obtain the information you need. Unless you are already super familiar with Github API or super lucky, you probably will do some trials and errors. Therefore, be prepared to go back and forth in studying the API documentation, testing, and revising until you obtain what you need.
#
# After receiving the JSON data object, you need to inspect its structure and decide how to parse the data.
#
# When you test your requests with Github API, sometimes you may be blocked by Github with an error message that reads:
#
# You have triggered an abuse detection mechanism and have been temporarily blocked from content creation. Please retry your request again later.
#
# Don't worry. Check the parameters in your request and wait for a minute or two before you make additional requests.
#
# After you find out the secrete files:
#
# Sort the filenames ascendingly.
#
# Read the content of each secret files into an array of strings.
#
# Concatenate the strings in the array separating each two with a whitespace.
#
# Print out the joke.
#
# Deliverables
# challenge-1.py or challenge-1.ipynb that contains your solution to Challenge 1.
#
# challenge-2.py or challenge-1.ipynb that contains your solution to Challenge 2.
#
# challenge-3.py or challenge-1.ipynb that contains your solution to Challenge 3.

# %%
    Url=f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
    #Url=f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{+path}'
    token='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'
    headers={"Authorization": "Bearer {}".format(token)}
    response=requests.get(Url, headers=headers)
    y=response.json()
# Out:
#           name        path                                       sha  size  \
# 0   .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1        15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2        15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3        17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4        30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
# 5        40303       40303  30193d9cf62b07bcbb6366513ff03596861f2d29     0
# 6        44639       44639  22fc3d5c2db80822c351edb2248f3491c8ebda86     0
# 7        45525       45525  6a4a88cd9084110c8646c3cfd84dfe96b300a4a7     0
# 8        47222       47222  c7001604cdadc2fe7b82e0f6996690718cac6941     0
# 9        47830       47830  f84882ad7560fd2b8c6a0867bc707ce9009ef288     0
# 10       49418       49418  46bc658c09589d9023246b00e848ce97d30d4989     0
# ...

# %%
y
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
url_list=[]

for i in y:
    for key,value in i.items():
        if key== 'url':
            url_list.append(value)
url_list
# Out:
# ['https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/40303?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/45525?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47830?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/49418?ref=master',
# ...

# %%
super_json=[]
for i in url_list[1:]:
    URL=i
    token='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'
    headers={"Authorization": "Bearer {}".format(token)}
    res=requests.get(URL, headers=headers)
    z=res.json()
    super_json.append(z)

super_json
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
filtered=[]
for i in super_json:
    for j in i:
        for key,value in j.items():
                if key=="size" and value>0:
                    filtered.append(j)
                    
filtered
# Out:
# [{'name': '.0006.scavengerhunt',
#   'path': '15024/.0006.scavengerhunt',
#   'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#   'size': 3,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
filtered = sorted(filtered, key=lambda k: k['name'])
filtered
# Out:
# [{'name': '.0001.scavengerhunt',
#   'path': '98750/.0001.scavengerhunt',
#   'sha': '2add7632f1323136324efbf38ec66db1838b6173',
#   'size': 3,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/98750/.0001.scavengerhunt',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/98750/.0001.scavengerhunt',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/98750/.0001.scavengerhunt'}},
# ...

# %%
final_urls=[]
for i in filtered:
    for key,value in i.items():
        if key=='download_url':
            final_urls.append(value)
final_urls
# Out:
# ['https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/98750/.0001.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/88596/.0002.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/60224/.0003.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/68848/.0004.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/44639/.0005.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/17020/.0007.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0008.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/97881/.0009.scavengerhunt',
# ...

# %%
text=[] 
for i in final_urls:
    URL=i
    GOLDENEGG=requests.get(URL)
    text.append(GOLDENEGG.text.strip())
text
# Out:
# ['In',
#  'data',
#  'science,',
#  '80',
#  'percent',
#  'of',
#  'time',
#  'spent',
#  'is',
#  'preparing',
#  'data,',
#  '20',
#  'percent',
#  'of',
#  'time',
#  'is',
#  'spent',
#  'complaining',
#  'about',
#  'the',
#  'need',
#  'to',
#  'prepare',
#  'data.']

# %%
" ".join(text)
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'

# %%
# import urllib

# text=[]
# for i in final_urls:
#     URL=i
#     f = urllib.request.urlopen(URL)        
#     myfile = f.read()
#     text.append(myfile)

# text
    
    
#     response.text.strip()

# %% [markdown]
# # IGNORE THIS SECTION ----------

# %%
f= open('output2.json')
data= json.load(f)
data
# Out:
# [{'id': 528225470,
#   'node_id': 'R_kgDOH3wUvg',
#   'name': 'lab-API_SCAVANGER',
#   'full_name': 'enrunz/lab-API_SCAVANGER',
#   'private': False,
#   'owner': {'login': 'enrunz',
#    'id': 105838147,
#    'node_id': 'U_kgDOBk72Qw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105838147?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enrunz',
#    'html_url': 'https://github.com/enrunz',
#    'followers_url': 'https://api.github.com/users/enrunz/followers',
#    'following_url': 'https://api.github.com/users/enrunz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/enrunz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/enrunz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/enrunz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/enrunz/orgs',
#    'repos_url': 'https://api.github.com/users/enrunz/repos',
# ...

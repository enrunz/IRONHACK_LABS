# %% [markdown]
# # Challenge: Rick and Morty API
#
# ![](http://as01.epimg.net/epik/imagenes/2019/02/12/portada/1549970850_227267_1549973816_noticia_normal.jpg)
#
#
# **In this challenge, you'll develop codes to parse and analyze data returned from the [Rick and Morty API](https://rickandmortyapi.com/).** The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
url= 'https://rickandmortyapi.com/api/character'
WebPage=requests.get(url)

# %%
WebPage.json()
# Out:
# {'info': {'count': 826,
#   'pages': 42,
#   'next': 'https://rickandmortyapi.com/api/character?page=2',
#   'prev': None},
#  'results': [{'id': 1,
#    'name': 'Rick Sanchez',
#    'status': 'Alive',
#    'species': 'Human',
#    'type': '',
#    'gender': 'Male',
#    'origin': {'name': 'Earth (C-137)',
#     'url': 'https://rickandmortyapi.com/api/location/1'},
#    'location': {'name': 'Citadel of Ricks',
#     'url': 'https://rickandmortyapi.com/api/location/3'},
#    'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg',
#    'episode': ['https://rickandmortyapi.com/api/episode/1',
#     'https://rickandmortyapi.com/api/episode/2',
#     'https://rickandmortyapi.com/api/episode/3',
#     'https://rickandmortyapi.com/api/episode/4',
#     'https://rickandmortyapi.com/api/episode/5',
#     'https://rickandmortyapi.com/api/episode/6',
#     'https://rickandmortyapi.com/api/episode/7',
#     'https://rickandmortyapi.com/api/episode/8',
# ...

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import requests
import json 
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %%
page1=requests.get('https://rickandmortyapi.com/api/character/?page=1')
flat_data=json_normalize(page1.json())
flat_data
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/1211225443.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flat_data=json_normalize(page1.json())
#                                              results  info.count  info.pages  \
# 0  [{'id': 1, 'name': 'Rick Sanchez', 'status': '...         826          42
#
#                                            info.next info.prev
# 0  https://rickandmortyapi.com/api/character/?page=2      None

# %% [markdown]
# # Number of pages is 42

# %%
page1=requests.get('https://rickandmortyapi.com/api/character/?page=1')
x=page1.json()
result=x['results']
flatten_data=json_normalize(result)
flatten_data
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/2897488304.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flatten_data=json_normalize(result)
#     id                       name   status species  \
# 0    1               Rick Sanchez    Alive   Human
# 1    2                Morty Smith    Alive   Human
# 2    3               Summer Smith    Alive   Human
# 3    4                 Beth Smith    Alive   Human
# 4    5                Jerry Smith    Alive   Human
# 5    6  Abadango Cluster Princess    Alive   Alien
# 6    7           Abradolf Lincler  unknown   Human
# 7    8           Adjudicator Rick     Dead   Human
# 8    9            Agency Director     Dead   Human
# 9   10                 Alan Rails     Dead   Human
# 10  11            Albert Einstein     Dead   Human
# 11  12                  Alexander     Dead   Human
# 12  13               Alien Googah  unknown   Alien
# ...

# %%
df=pd.DataFrame()
for i in range(1,43):
    page=requests.get(f'https://rickandmortyapi.com/api/character/?page={i}')
    x=page.json()
    RESULT=x['results']
    main=pd.json_normalize(RESULT)
    
    df=df.append(main)
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/4091287809.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(main)
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/4091287809.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(main)
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/4091287809.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(main)
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/4091287809.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(main)
# ...

# %%
df
# Out:
#      id          name   status species                  type      gender  \
# 0     1  Rick Sanchez    Alive   Human                              Male
# 1     2   Morty Smith    Alive   Human                              Male
# 2     3  Summer Smith    Alive   Human                            Female
# 3     4    Beth Smith    Alive   Human                            Female
# 4     5   Jerry Smith    Alive   Human                              Male
# ..  ...           ...      ...     ...                   ...         ...
# 1   822   Young Jerry  unknown   Human                              Male
# 2   823    Young Beth  unknown   Human                            Female
# 3   824    Young Beth  unknown   Human                            Female
# 4   825   Young Jerry  unknown   Human                              Male
# 5   826  Butter Robot    Alive   Robot  Passing Butter Robot  Genderless
#
#                                                 image  \
# ...

# %% [markdown]
# # OTHER WAY TO GET THE SAME INITIAL TABLE

# %%
def flatten(data,col_list):
    for column in col_list:
        flattened=pd.DataFrame(dict(data[column]))
        columns=[str(col) for col in flattened.columns ]
        flattened.columns=[column+'_'+colname for colname in columns]
        data=pd.concat([data,flattened],axis=1)
        data=data.drop(column,axis=1)
    return data

# %%
nested_columns=['results']
df= flatten(flat_data, nested_columns)
df2=df['results_0']
df2
# Out:
# 0     {'id': 1, 'name': 'Rick Sanchez', 'status': 'A...
# 1     {'id': 2, 'name': 'Morty Smith', 'status': 'Al...
# 2     {'id': 3, 'name': 'Summer Smith', 'status': 'A...
# 3     {'id': 4, 'name': 'Beth Smith', 'status': 'Ali...
# 4     {'id': 5, 'name': 'Jerry Smith', 'status': 'Al...
# 5     {'id': 6, 'name': 'Abadango Cluster Princess',...
# 6     {'id': 7, 'name': 'Abradolf Lincler', 'status'...
# 7     {'id': 8, 'name': 'Adjudicator Rick', 'status'...
# 8     {'id': 9, 'name': 'Agency Director', 'status':...
# 9     {'id': 10, 'name': 'Alan Rails', 'status': 'De...
# 10    {'id': 11, 'name': 'Albert Einstein', 'status'...
# 11    {'id': 12, 'name': 'Alexander', 'status': 'Dea...
# 12    {'id': 13, 'name': 'Alien Googah', 'status': '...
# 13    {'id': 14, 'name': 'Alien Morty', 'status': 'u...
# 14    {'id': 15, 'name': 'Alien Rick', 'status': 'un...
# 15    {'id': 16, 'name': 'Amish Cyborg', 'status': '...
# 16    {'id': 17, 'name': 'Annie', 'status': 'Alive',...
# ...

# %%
Flat=json_normalize(df2)
Flat
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/1852997864.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   Flat=json_normalize(df2)
#     id                       name   status species  \
# 0    1               Rick Sanchez    Alive   Human
# 1    2                Morty Smith    Alive   Human
# 2    3               Summer Smith    Alive   Human
# 3    4                 Beth Smith    Alive   Human
# 4    5                Jerry Smith    Alive   Human
# 5    6  Abadango Cluster Princess    Alive   Alien
# 6    7           Abradolf Lincler  unknown   Human
# 7    8           Adjudicator Rick     Dead   Human
# 8    9            Agency Director     Dead   Human
# 9   10                 Alan Rails     Dead   Human
# 10  11            Albert Einstein     Dead   Human
# 11  12                  Alexander     Dead   Human
# 12  13               Alien Googah  unknown   Alien
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The character who appeared in most episodes (aside from Rick and Morty, of course!).
#
# * The total number of dead characters.
#
# * A list of all character origins (without duplicates).

# %%
df.keys()
# Out:
# Index(['id', 'name', 'status', 'species', 'type', 'gender', 'image', 'episode',
#        'url', 'created', 'origin.name', 'origin.url', 'location.name',
#        'location.url'],
#       dtype='object')

# %%
df[['name','status','episode','origin.name']]
# Out:
#             name   status                                            episode  \
# 0   Rick Sanchez    Alive  [https://rickandmortyapi.com/api/episode/1, ht...
# 1    Morty Smith    Alive  [https://rickandmortyapi.com/api/episode/1, ht...
# 2   Summer Smith    Alive  [https://rickandmortyapi.com/api/episode/6, ht...
# 3     Beth Smith    Alive  [https://rickandmortyapi.com/api/episode/6, ht...
# 4    Jerry Smith    Alive  [https://rickandmortyapi.com/api/episode/6, ht...
# ..           ...      ...                                                ...
# 1    Young Jerry  unknown       [https://rickandmortyapi.com/api/episode/51]
# 2     Young Beth  unknown       [https://rickandmortyapi.com/api/episode/51]
# 3     Young Beth  unknown       [https://rickandmortyapi.com/api/episode/51]
# 4    Young Jerry  unknown       [https://rickandmortyapi.com/api/episode/51]
# 5   Butter Robot    Alive        [https://rickandmortyapi.com/api/episode/9]
#
#                       origin.name
# ...

# %%
df.groupby(['status']).size()
# Out:
# status
# Alive      439
# Dead       287
# unknown    100
# dtype: int64

# %% [markdown]
# # There are 287 dead characters

# %%
uniq_origins=np.unique(df['origin.name'].values)
print(len(uniq_origins))
print(uniq_origins)
# Out:
# 97
# ['Abadango' 'Alphabetrium' 'Anatomy Park' 'Avian Planet' 'Bepis 9'
#  'Bird World' "Birdperson's Consciousness" 'Citadel of Ricks'
#  'Cronenberg Earth' 'Detoxifier' 'Draygon' 'Earth (5-126)' 'Earth (C-137)'
#  'Earth (C-500A)' 'Earth (Chair Dimension)' 'Earth (D-99)' 'Earth (D716)'
#  'Earth (D716-B)' 'Earth (D716-C)' "Earth (Evil Rick's Target Dimension)"
#  'Earth (Fascist Dimension)' 'Earth (Fascist Shrimp Dimension)'
#  'Earth (Fascist Teddy Bear Dimension)'
#  'Earth (Giant Telepathic Spiders Dimension)' 'Earth (J-22)'
#  'Earth (J19ζ7)' 'Earth (K-22)' 'Earth (K-83)' 'Earth (Phone Dimension)'
#  'Earth (Pizza Dimension)' 'Earth (Replacement Dimension)'
#  'Earth (Tusk Dimension)' 'Earth (Unknown dimension)'
#  'Earth (Wasp Dimension)' 'Elemental Rings' 'Eric Stoltz Mask Earth'
#  'Fantasy World' 'Ferkus 9' 'France' 'Gaia' 'Gazorpazorp' 'Gear World'
#  "Giant's Town" 'Girvonesk' 'Glaagablaaga' 'Globaflyn' 'Glorzo Asteroid'
# ...

# %%
episodes=df[['name','episode']]
flat_episodes=df[['episode']]
type(flat_episodes)
# Out:
# pandas.core.frame.DataFrame

# %%
episodes
episodes_expanded_v1 = episodes["episode"].apply(pd.Series)
episodes_expanded_v1
# Out:
#                                             0   \
# 0    https://rickandmortyapi.com/api/episode/1
# 1    https://rickandmortyapi.com/api/episode/1
# 2    https://rickandmortyapi.com/api/episode/6
# 3    https://rickandmortyapi.com/api/episode/6
# 4    https://rickandmortyapi.com/api/episode/6
# ..                                         ...
# 1   https://rickandmortyapi.com/api/episode/51
# 2   https://rickandmortyapi.com/api/episode/51
# 3   https://rickandmortyapi.com/api/episode/51
# 4   https://rickandmortyapi.com/api/episode/51
# 5    https://rickandmortyapi.com/api/episode/9
#
#                                            1   \
# 0   https://rickandmortyapi.com/api/episode/2
# 1   https://rickandmortyapi.com/api/episode/2
# 2   https://rickandmortyapi.com/api/episode/7
# 3   https://rickandmortyapi.com/api/episode/7
# 4   https://rickandmortyapi.com/api/episode/7
# ..                                        ...
# 1                                         NaN
# ...

# %%
freq=episodes_expanded_v1.count(axis=1)
freq
# Out:
# 0    51
# 1    51
# 2    42
# 3    42
# 4    39
#      ..
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# Length: 826, dtype: int64

# %%
episodes['freq']=freq
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_40416/2844516493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   episodes['freq']=freq

# %%
episodes
# Out:
#             name                                            episode  freq
# 0   Rick Sanchez  [https://rickandmortyapi.com/api/episode/1, ht...    51
# 1    Morty Smith  [https://rickandmortyapi.com/api/episode/1, ht...    51
# 2   Summer Smith  [https://rickandmortyapi.com/api/episode/6, ht...    42
# 3     Beth Smith  [https://rickandmortyapi.com/api/episode/6, ht...    42
# 4    Jerry Smith  [https://rickandmortyapi.com/api/episode/6, ht...    39
# ..           ...                                                ...   ...
# 1    Young Jerry       [https://rickandmortyapi.com/api/episode/51]     1
# 2     Young Beth       [https://rickandmortyapi.com/api/episode/51]     1
# 3     Young Beth       [https://rickandmortyapi.com/api/episode/51]     1
# 4    Young Jerry       [https://rickandmortyapi.com/api/episode/51]     1
# 5   Butter Robot        [https://rickandmortyapi.com/api/episode/9]     1
#
# [826 rows x 3 columns]

# %%
episodes.sort_values(by=["freq"])
episodes
# Out:
#             name                                            episode  freq
# 0   Rick Sanchez  [https://rickandmortyapi.com/api/episode/1, ht...    51
# 1    Morty Smith  [https://rickandmortyapi.com/api/episode/1, ht...    51
# 2   Summer Smith  [https://rickandmortyapi.com/api/episode/6, ht...    42
# 3     Beth Smith  [https://rickandmortyapi.com/api/episode/6, ht...    42
# 4    Jerry Smith  [https://rickandmortyapi.com/api/episode/6, ht...    39
# ..           ...                                                ...   ...
# 1    Young Jerry       [https://rickandmortyapi.com/api/episode/51]     1
# 2     Young Beth       [https://rickandmortyapi.com/api/episode/51]     1
# 3     Young Beth       [https://rickandmortyapi.com/api/episode/51]     1
# 4    Young Jerry       [https://rickandmortyapi.com/api/episode/51]     1
# 5   Butter Robot        [https://rickandmortyapi.com/api/episode/9]     1
#
# [826 rows x 3 columns]

# %%
# Summer Smith is the character after Rick and Morty

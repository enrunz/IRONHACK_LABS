# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(('int64','float64'))
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes('object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
fig=plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.style.use('classic')
fig=plt.figure(figsize=(12,6))
plt.subplot(1,3,1) #plt.subplot(filas,columnas,#de panel)
plt.hist(titanic['Age'],density='normed',bins=10)
plt.subplot(1,3,2)
plt.hist(titanic['Age'],density='normed',bins=20)
plt.subplot(1,3,3)
plt.hist(titanic['Age'],density='normed',bins=50)
plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# It does to a certain extent. If you add more bins,it shows with further detail where the most values are withing each bin. You get a better understanding how the data is distributed. The broader the category the less info we have but also the more manageable the info.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here

sns.displot(Titanic, x=titanic["Age"])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].hist()
# Out:
# <AxesSubplot:>

# %%
# your code here- 2nd way
labels = ['male', 'female']
colors = sns.color_palette('pastel')[0:5]
plt.pie(titanic['Gender'].value_counts(), labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
# your code here
labels = ['3rd', '1st','2nd']
colors = sns.color_palette('pastel')[0:5]
plt.pie(titanic['Pclass'].value_counts(), labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
sns.set_theme(style="whitegrid")

ax = sns.boxplot(x=titanic["Age"])

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %% [markdown]
# It tells me most passangers were young. Half of the passangers were between 22 and 38 years old. 75% of the passengers were younger than 38. It also shows there were a few outliers.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.displot(Titanic, x=titanic["Age"])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# Well I can see the specific number of people per age range. And the age ranges are much more specific. For instance I know there were over 150 passengers between the age of 22.5-25. In fact I could know even more. I know the second largest group is very late 20's directly followed by early thirties. A bunch of info.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

sns.jointplot('Age','Fare',data=titanic,kind='reg')
# Out:
# /Users/derinkivaner/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# your code-2nd way
x = titanic['Age']
y = titanic['Fare']
plt.scatter(x,y)
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
#your code here

sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# plt.matshow(titanic.corr())
# plt.show()

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# The two most correlated features are Pclass and Fare, the higher the fare the higher the class(although the lower the number since class 1 is considered higher. Hence the negative correlation). In close second the passenger class and age: The older the higher the class (considering 1 as the high class). This was followed by Parch and the SibSp.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
fclass=titanic[(titanic['Pclass']==1)]['Age'].reset_index()
ax = sns.boxplot(x=fclass["Age"])
ax.set_title("FIRST CLASS")
# Out:
# Text(0.5, 1.0, 'FIRST CLASS')

# %%
sclass=titanic[(titanic['Pclass']==2)]['Age'].reset_index()
ax2 = sns.boxplot(x=sclass["Age"])
ax2.set_title("SECOND CLASS")
# Out:
# Text(0.5, 1.0, 'SECOND CLASS')

# %%
tclass=titanic[(titanic['Pclass']==3)]['Age'].reset_index()
ax3 = sns.boxplot(x=sclass["Age"])
ax3.set_title("THIRD CLASS")
# Out:
# Text(0.5, 1.0, 'THIRD CLASS')

# %%
multigrafic=sns.FacetGrid(titanic,row="Pclass",margin_titles=True)
multigrafic.map(plt.hist,'Age')

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
multigrafic=sns.FacetGrid(titanic,row="Gender",margin_titles=True)
multigrafic.map(plt.hist,'Age')

# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
page=requests.get(url).content
page
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-5178aee0ee76.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-217d4f9c8e70.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code

soup= BeautifulSoup(page,'html')
names= [element.text for element in soup.find_all('h1',{'class':'h3 lh-condensed'})]
names_clean=[i.strip() for i in names]
names_clean
# Out:
# ['Stephen Celis',
#  'RangiLyu',
#  'chencheng (云谦)',
#  'Stefan Prodan',
#  'Alex Gaynor',
#  'Lachlan Miller',
#  'Alon Zakai',
#  'Bram Gerritsen',
#  'Jan-Erik Rediger',
#  'Robin Malfait',
#  'Amin Alaee',
#  'Steve Macenski',
#  'Jaco',
#  'Nathan Rajlich',
#  'Charles Tapley Hoyt',
#  'James N',
#  'Segun Adebayo',
#  'James Newton-King',
#  'Aleksandr Statciuk',
#  'YK',
#  'hualin.zhu',
#  'Nicolas Gallagher',
#  'David Sherret',
#  'Joe Chen',
#  'Azure SDK Bot']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url2 = 'https://github.com/trending/python?since=daily'

# %%
#your code
page2=requests.get(url2).content
page2
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-5178aee0ee76.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-217d4f9c8e70.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="
# ...

# %%
soup2= BeautifulSoup(page2,'html')
names2= [element.text for element in soup2.find_all('h1',{'class':'h3 lh-condensed'})]
names_clean2=[i.strip().replace('\n\n''     ','') for i in names2]
names_clean2
# Out:
# ['t3l3machus / hoaxshell',
#  'rxrw / daily_morning',
#  'google-research / multinerf',
#  'microsoft / nni',
#  'sqlfluff / sqlfluff',
#  'limoest / daily_reminder',
#  'dbt-labs / dbt-utils',
#  'hummingbot / hummingbot',
#  'towhee-io / towhee',
#  'mouredev / Hello-Python',
#  'tiangolo / fastapi',
#  'apache / airflow',
#  'pittcsc / Summer2023-Internships',
#  'ansible / ansible',
#  'TencentARC / GFPGAN',
#  'saleor / saleor',
#  'locustio / locust',
#  'saltstack / salt',
#  'POSTECH-CVLab / PeRFception',
#  'PaddlePaddle / PaddleSpeech',
#  'Lightning-AI / lightning',
#  'MVIG-SJTU / AlphaPose',
#  'RangiLyu / nanodet',
#  'Megvii-BaseDetection / YOLOX',
#  'cl2333 / Grokking-the-Coding-Interview-Patterns-for-Coding-Questions']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url3 = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
page3=requests.get(url3).content
page3
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Walt Disney - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"6d318c16-4c5b-492b-af50-6f4947cce503","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Walt_Disney","wgTitle":"Walt Disney","wgCurRevisionId":1106407749,"wgRevisionId":1106407749,"wgArticleId":32917,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages containing links to subscription-only content","Articles with short description","Short description matches Wikidata","Featured articles","Wikiped
# ...

# %%
soup3= BeautifulSoup(page3,'html')
images= [element.get('src') for element in soup3.find_all('img')]

#images_clean=[i.strip().replace('\n\n''     ','') for i in names2]
#images_clean
images
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url4 ='https://en.wikipedia.org/wiki/Python'
def starter(url):
    page=requests.get(url).content
    return BeautifulSoup(page,'html')

# %%
#your code
soup4=starter(url4)
links=[element.get('href') for element in soup4.find_all('a',attrs={'href': re.compile('^https://')})]
links
# Out:
# ['https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0',
#  'https://en.wikipedia.org/w/index.php?title=Python&oldid=1104201971',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452',
#  'https://commons.wikimedia.org/wiki/Category:Python',
#  'https://af.wikipedia.org/wiki/Python',
#  'https://als.wikipedia.org/wiki/Python',
#  'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D8%AA%D9%88%D8%B6%D9%8A%D8%AD)',
#  'https://az.wikipedia.org/wiki/Python',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %% [markdown]
# # ASK ABOUT THIS ONE

# %%
# This is the url you will scrape in this exercise
url5 = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
page5=requests.get(url5).content
soup5= BeautifulSoup(page5,'html')
num_tit = [re.findall('[0-9]+', i.text) for i in soup5.find_all(class_='usctitle')]
print(num_tit[-1])

total_req= len(num_tit)-1
total_req
#num_tit_clean = [re.compile(i) for i in num_tit]
#element.text for element in
# Out:
# ['54']
# 50

# %% [markdown]
# # NOTE: the number abobve changed because the page changed something.

# %%
# #your code
# page5=requests.get(url5).content
# soup5= BeautifulSoup(page5,'html')
# num_tit = [soup5.find_all('div', id="us/usc/t")]
                       
# #num_tit_clean = [re.compile(i) for i in num_tit]
# #element.text for element in 
# num_tit

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url6 = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
soup6=starter(url6)

top_ten= [i.text.strip() for i in soup6.find_all('h3',{'class':'title'})]
top_ten
# Out:
# ['ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'OMAR ALEXANDER CARDENAS',
#  'ALEJANDRO ROSALES CASTILLO',
#  'RUJA IGNATOVA',
#  'JASON DEREK BROWN',
#  'ARNOLDO JIMENEZ',
#  'RAFAEL CARO-QUINTERO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url7 = 'https://www.emsc-csem.org/Earthquake/'
soup7=starter(url7)

# %%
earth_table = soup7.find_all('table')[3]
rows = earth_table.find("tbody").find_all("tr")
rows_info = []
for i in rows:
    td = i.find_all('td')
    row = [str(i.get_text()).strip() for i in td]
    rows_info.append(row[3:])
    
for i in rows_info:
    del i[6]
    
df = pd.DataFrame(rows_info)
df.head(10)
# Out:
#                                                 0      1  2       3  4    5  \
# 0      earthquake2022-08-27   16:12:05.342min ago  35.44  N    3.63  W   16
# 1      earthquake2022-08-27   16:05:41.048min ago  38.67  N   28.20  W    9
# 2  earthquake2022-08-27   15:50:21.01hr 03min ago   0.13  S  123.34  E  123
# 3  earthquake2022-08-27   15:47:09.71hr 07min ago  28.38  N   51.58  E    8
# 4  earthquake2022-08-27   15:42:15.01hr 11min ago   1.56  N  127.20  E  113
# 5  earthquake2022-08-27   15:41:46.01hr 12min ago   5.69  S  102.61  E   37
# 6  earthquake2022-08-27   15:29:42.71hr 24min ago  35.44  N    3.58  W    6
# 7  earthquake2022-08-27   15:24:55.31hr 29min ago  27.99  N   56.83  E   16
# 8  earthquake2022-08-27   15:03:28.01hr 50min ago  15.34  N   94.87  W   16
# 9  earthquake2022-08-27   15:01:58.11hr 52min ago  44.79  N  110.81  W    8
#
#      6                               7                 8
# 0  2.0             STRAIT OF GIBRALTAR  2022-08-27 16:31
# ...

# %%
table_header
# Out:
# ['Date & Time UTC',
#  'Latitude degrees',
#  'Longitude degrees',
#  'Depth km',
#  'Mag  [+]',
#  'Region name  [+]',
#  'Last update [-]']

# %%
df[1] = df[1]+df[2]
df.drop(2, inplace=True, axis=1)
df[3] = df[3]+df[4]
df.drop(4, inplace=True, axis=1)
df.columns = table_header
df.head(20)
# Out:
#                                    Date & Time UTC Latitude degrees  \
# 0       earthquake2022-08-27   16:12:05.342min ago           35.44N
# 1       earthquake2022-08-27   16:05:41.048min ago           38.67N
# 2   earthquake2022-08-27   15:50:21.01hr 03min ago            0.13S
# 3   earthquake2022-08-27   15:47:09.71hr 07min ago           28.38N
# 4   earthquake2022-08-27   15:42:15.01hr 11min ago            1.56N
# 5   earthquake2022-08-27   15:41:46.01hr 12min ago            5.69S
# 6   earthquake2022-08-27   15:29:42.71hr 24min ago           35.44N
# 7   earthquake2022-08-27   15:24:55.31hr 29min ago           27.99N
# 8   earthquake2022-08-27   15:03:28.01hr 50min ago           15.34N
# 9   earthquake2022-08-27   15:01:58.11hr 52min ago           44.79N
# 10  earthquake2022-08-27   14:46:35.82hr 07min ago           29.43S
# 11  earthquake2022-08-27   14:39:40.02hr 14min ago            8.26S
# 12  earthquake2022-08-27   14:36:47.22hr 17min ago           19.17N
# ...

# %% [markdown]
# # THE FOLLLOWINGS ARE FAILED ATTEMPTS

# %%
#your code
table_header= [i.text for i in soup7.find_all('th')][1:]
#table_data= [i.text for i in soup7.find_all('tbody',{'class':'ligne1 normal'})]

table_data= [i.text for i in soup7.find_all('tbody')]
earthquakes=[]
for j in table_data:
    earthquakes.append(j)

y=[earthquakes[0].split('earthquake')]
last_quakes=y[0]
last_quakes.remove(last_quakes[0])


clean_last_quakes=[]
for i in last_quakes:
    separation=i.strip().replace('\xa0','SEP').replace('ago','ago SEP').replace('N ','N SEP').replace('S ','S SEP').replace('W ','W SEP').replace('E ','E SEP')
    clean_last_quakes.append(separation)

clean2=[]
for i in clean_last_quakes:
    SEP2=i.replace('SEPSEPSEP',' DIV ').replace('SEPSEP',' DIV ').replace('SEPN','N').replace('SEPS','S').replace('SEPE','E').replace('SEPW','W').replace('ML',' DIV ')
    clean2.append(SEP2)
    
clean2
# Out:
#                                                     0
# 0   2022-08-27   16:12:05.342min ago35.44 N  3.63 ...
# 1   2022-08-27   16:05:41.048min ago38.67 N  28.20...
# 2   2022-08-27   15:50:21.01hr 03min ago0.13 S  12...
# 3   2022-08-27   15:47:09.71hr 07min ago28.38 N  5...
# 4   2022-08-27   15:42:15.01hr 11min ago1.56 N  12...
# 5   2022-08-27   15:41:46.01hr 12min ago5.69 S  10...
# 6   2022-08-27   15:29:42.71hr 24min ago35.44 N  3...
# 7   2022-08-27   15:24:55.31hr 29min ago27.99 N  5...
# 8   2022-08-27   15:03:28.01hr 50min ago15.34 N  9...
# 9   2022-08-27   15:01:58.11hr 52min ago44.79 N  1...
# 10  2022-08-27   14:46:35.82hr 07min ago29.43 S  7...
# 11  2022-08-27   14:39:40.02hr 14min ago8.26 S  10...
# 12  2022-08-27   14:36:47.22hr 17min ago19.17 N  1...
# 13  2022-08-27   14:30:09.72hr 24min ago46.60 N  2...
# 14  2022-08-27   14:18:24.22hr 35min ago17.97 N  6...
# 15  2022-08-27   14:10:14.82hr 43min ago17.95 N  6...
# ...

# %%
y=[earthquakes[0].replace('\xa0','').split('earthquake')]
last_quakes=y[0]
last_quakes

clean_last_quakes=[]
for i in last_quakes:
    test=i.strip().split('.')
    clean_last_quakes.append(test)
clean_last_quakes.remove(clean_last_quakes[0])
clean_last_quakes
quakesdf=pd.DataFrame(clean_last_quakes[0:20])
quakesdf
# Out:
#                      0                 1       2          3  \
# 0   2022-08-2716:12:05      342min ago35    44N3   63W16ML2
# 1   2022-08-2716:05:41      048min ago38   67N28    20W9ML2
# 2   2022-08-2715:50:21   01hr 03min ago0  13S123  34E123 M3
# 3   2022-08-2715:47:09  71hr 07min ago28   38N51    58E8ML3
# 4   2022-08-2715:42:15   01hr 11min ago1  56N127  20E113 M2
# 5   2022-08-2715:41:46   01hr 12min ago5  69S102   61E37 M3
# 6   2022-08-2715:29:42  71hr 24min ago35    44N3    58W6ML2
# 7   2022-08-2715:24:55  31hr 29min ago27   99N56   83E16ML4
# 8   2022-08-2715:03:28  01hr 50min ago15   34N94   87W16 M4
# 9   2022-08-2715:01:58  11hr 52min ago44  79N110    81W8Ml2
# 10  2022-08-2714:46:35  82hr 07min ago29   43S71   64W80mb4
# 11  2022-08-2714:39:40   02hr 14min ago8  26S107   72E24 M3
# 12  2022-08-2714:36:47  22hr 17min ago19  17N155   48W36Md2
# 13  2022-08-2714:30:09  72hr 24min ago46   60N29   43E20ML2
# 14  2022-08-2714:18:24  22hr 35min ago17   97N66   73W14Md2
# ...

# %%
clean_last_quakes=[]
for i in last_quakes:
    separation=i.strip().replace('\xa0','SEP').replace('ago','ago SEP').replace('N ','N SEP').replace('S ','S SEP').replace('W ','W SEP').replace('E ','E SEP')
    clean_last_quakes.append(separation)

clean2=[]
for i in clean_last_quakes:
    SEP2=i.replace('SEPSEPSEP',' DIV ').replace('SEPSEP',' DIV ').replace('SEPN','N').replace('SEPS','S').replace('SEPE','E').replace('SEPW','W').replace('ML',' DIV ')
    clean2.append(SEP2)
    
clean2
# Out:
# ['',
#  '2022-08-2716:12:05.342min ago SEP35.44N3.63W16 DIV 2.0STRAIT OF GIBRALTAR2022-08-27 16:31',
#  '2022-08-2716:05:41.048min ago SEP38.67N28.20W9 DIV 2.7AZORES SEPISLANDS, PORTUGAL2022-08-27 16:11',
#  '2022-08-2715:50:21.01hr 03min ago SEP0.13S123.34E123 M3.6SULAWESI, INDONESIA2022-08-27 16:00',
#  '2022-08-2715:47:09.71hr 07min ago SEP28.38N51.58E8 DIV 3.6SOUTHERN SEPIRAN2022-08-27 16:01',
#  '2022-08-2715:42:15.01hr 11min ago SEP1.56N127.20E113 M2.5HALMAHERA, INDONESIA2022-08-27 15:50',
#  '2022-08-2715:41:46.01hr 12min ago SEP5.69S102.61E37 M3.9SOUTHERN SUMATRA, INDONESIA2022-08-27 15:50',
#  '2022-08-2715:29:42.71hr 24min ago SEP35.44N3.58W6 DIV 2.6STRAIT OF GIBRALTAR2022-08-27 15:51',
#  '2022-08-2715:24:55.31hr 29min ago SEP27.99N56.83E16 DIV 4.0SOUTHERN SEPIRAN2022-08-27 15:40',
#  '2022-08-2715:03:28.01hr 50min ago SEP15.34N94.87W16 M4.1OFFSHORE SEPOAXACA, MEXICO2022-08-27 15:20',
# ...

# %% [markdown]
# # FAILS END HERE

# %% [markdown]
# # SKIP THIS ONE

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url8 = 'https://twitter.com/rosalia'

# %%
soup8=starter(url8)

# %%
soup8
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head><meta charset="utf-8"/>
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome('/Users/derinkivaner/Desktop/IH/PYTHON/WEB_SCRAPING/chromedriver')
driver.get('https://twitter.com/rosalia')
time.sleep(4)
source = driver.page_source

driver.quit()
# Out:
# /var/folders/51/zl81hkbj365fyht29sw2pjsw0000gn/T/ipykernel_41082/3042904751.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/derinkivaner/Desktop/IH/PYTHON/WEB_SCRAPING/chromedriver')

# %%
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://twitter.com/rosalia')
#source = driver.page_source
time.sleep(7)
#soup8 = BeautifulSoup(source, "html")
#tweets = [tweet.text for tweet in driver.find_element("div")]
driver.find_element(By.CLASS_NAME("css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0"))
#tweets

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [201], in <cell line: 7>()
#       4 time.sleep(7)
#       5 #soup8 = BeautifulSoup(source, "html")
#       6 #tweets = [tweet.text for tweet in driver.find_element("div")]
# ----> 7 driver.find_element(By.CLASS_NAME("css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0"))
#       8 #tweets
#      10 driver.quit()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url9 = 'https://www.wikipedia.org/'

# %%
soup9=starter(url9)

# %%
lang=[i.text.strip().split('\n') for i in soup9.find_all('div',{'class':'central-featured-lang'})]
for i in lang:
    i[1]=i[1].replace('\xa0',' ')
lang
# Out:
# [['English', '6 458 000+ articles'],
#  ['日本語', '1 314 000+ 記事'],
#  ['Español', '1 755 000+ artículos'],
#  ['Русский', '1 798 000+ статей'],
#  ['Deutsch', '2 667 000+ Artikel'],
#  ['Français', '2 400 000+ articles'],
#  ['Italiano', '1 742 000+ voci'],
#  ['中文', '1 256 000+ 条目 / 條目'],
#  ['Português', '1 085 000+ artigos'],
#  ['العربية', '1 159 000+ مقالة']]

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url10 = 'https://data.gov.uk/'

# %%
soup10=starter(url10)
dbkinds=[i.text for i in soup10.find_all('h3')]
dbkinds
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url11 = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
soup11=starter(url11)
top10=[i.text.strip() for i in soup11.find_all('tr')]
top=[]
for i in top10:
    y=i.split('\n\n')
    top.append(y)
top
# Out:
# [['Rank',
#   'Language',
#   'Native Speakers(millions)',
#   'Percentageof world pop.(March 2019)[10]',
#   'Language family',
#   'Branch'],
#  ['1', 'Mandarin Chinese', '929.0', '11.922%', 'Sino-Tibetan', 'Sinitic'],
#  ['2', 'Spanish', '474.7', '5.994%', 'Indo-European', 'Romance'],
#  ['3', 'English', '372.9', '4.922%', 'Indo-European', 'Germanic'],
#  ['4',
#   'Hindi (Sanskritised Hindustani)[11]',
#   '343.9',
#   '4.429%',
#   'Indo-European',
#   'Indo-Aryan'],
#  ['5', 'Bengali', '233.7', '4.000%', 'Indo-European', 'Indo-Aryan'],
#  ['6', 'Portuguese', '232.4', '2.870%', 'Indo-European', 'Romance'],
#  ['7', 'Russian', '154.0', '2.000%', 'Indo-European', 'Balto-Slavic'],
#  ['8', 'Japanese', '125.3', '1.662%', 'Japonic', 'Japanese'],
#  ['9', 'Western Punjabi[12]', '92.7', '1.204%', 'Indo-European', 'Indo-Aryan'],
#  ['10', 'Yue Chinese', '85.2', '0.949%', 'Sino-Tibetan', 'Sinitic'],
#  ['11', 'Vietnamese', '84.6', '0.987%', 'Austroasiatic', 'Vietic'],
# ...

# %%
columns=top[0]
rows=top[1:]
wiki_df = pd.DataFrame(rows, columns=columns)
wiki_df.head(10)
# Out:
#   Rank                             Language Native Speakers(millions)  \
# 0    1                     Mandarin Chinese                     929.0
# 1    2                              Spanish                     474.7
# 2    3                              English                     372.9
# 3    4  Hindi (Sanskritised Hindustani)[11]                     343.9
# 4    5                              Bengali                     233.7
# 5    6                           Portuguese                     232.4
# 6    7                              Russian                     154.0
# 7    8                             Japanese                     125.3
# 8    9                  Western Punjabi[12]                      92.7
# 9   10                          Yue Chinese                      85.2
#
#   Percentageof world pop.(March 2019)[10] Language family        Branch
# 0                                 11.922%    Sino-Tibetan       Sinitic
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
